# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-Necessary-Packages" data-toc-modified-id="Importing-Necessary-Packages-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing Necessary Packages</a></span></li><li><span><a href="#Creating-Functions" data-toc-modified-id="Creating-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Creating Functions</a></span></li><li><span><a href="#Import-Data" data-toc-modified-id="Import-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Import Data</a></span><ul class="toc-item"><li><span><a href="#Import-Low-Level-Data" data-toc-modified-id="Import-Low-Level-Data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Import Low-Level Data</a></span></li><li><span><a href="#Import-Mid-Level-Data" data-toc-modified-id="Import-Mid-Level-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Import Mid-Level Data</a></span></li><li><span><a href="#Import-Ratings-Data" data-toc-modified-id="Import-Ratings-Data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Import Ratings Data</a></span></li></ul></li><li><span><a href="#Standardizing-Data" data-toc-modified-id="Standardizing-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Standardizing Data</a></span><ul class="toc-item"><li><span><a href="#Standardizing-Low-Level-Data" data-toc-modified-id="Standardizing-Low-Level-Data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Standardizing Low-Level Data</a></span></li><li><span><a href="#Standardizing-Mid-Level-Data" data-toc-modified-id="Standardizing-Mid-Level-Data-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Standardizing Mid-Level Data</a></span></li><li><span><a href="#Standardizing-Rating-Data" data-toc-modified-id="Standardizing-Rating-Data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Standardizing Rating Data</a></span></li></ul></li><li><span><a href="#PCA-for-Mid-Level-Features" data-toc-modified-id="PCA-for-Mid-Level-Features-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>PCA for Mid-Level Features</a></span></li><li><span><a href="#Correlation-Matrix-for-Mid-Level-Feats" data-toc-modified-id="Correlation-Matrix-for-Mid-Level-Feats-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Correlation Matrix for Mid-Level Feats</a></span></li><li><span><a href="#Concatenating-all-DataFrames-to-prep-for-OLS" data-toc-modified-id="Concatenating-all-DataFrames-to-prep-for-OLS-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Concatenating all DataFrames to prep for OLS</a></span><ul class="toc-item"><li><span><a href="#Sidewalk" data-toc-modified-id="Sidewalk-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Sidewalk</a></span></li><li><span><a href="#Road" data-toc-modified-id="Road-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Road</a></span></li><li><span><a href="#Emily-Talen-Imgs" data-toc-modified-id="Emily-Talen-Imgs-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Emily Talen Imgs</a></span></li><li><span><a href="#Omid-Images-(Img307)" data-toc-modified-id="Omid-Images-(Img307)-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Omid Images (Img307)</a></span></li></ul></li><li><span><a href="#Assigning-'Preference'-to-A-Respective-Variable" data-toc-modified-id="Assigning-'Preference'-to-A-Respective-Variable-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Assigning 'Preference' to A Respective Variable</a></span><ul class="toc-item"><li><span><a href="#Sidewalk---Preference" data-toc-modified-id="Sidewalk---Preference-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Sidewalk - Preference</a></span></li><li><span><a href="#Road---Preference" data-toc-modified-id="Road---Preference-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Road - Preference</a></span></li><li><span><a href="#Emily-Talen-Imgs---Preference" data-toc-modified-id="Emily-Talen-Imgs---Preference-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Emily Talen Imgs - Preference</a></span></li><li><span><a href="#Omid-Images---Preference" data-toc-modified-id="Omid-Images---Preference-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Omid Images - Preference</a></span></li></ul></li><li><span><a href="#Running-OLS-Regressions" data-toc-modified-id="Running-OLS-Regressions-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Running OLS Regressions</a></span><ul class="toc-item"><li><span><a href="#Sidewalk-OLS" data-toc-modified-id="Sidewalk-OLS-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Sidewalk OLS</a></span><ul class="toc-item"><li><span><a href="#Sidewalk-Low-Level-and-Preference" data-toc-modified-id="Sidewalk-Low-Level-and-Preference-9.1.1"><span class="toc-item-num">9.1.1&nbsp;&nbsp;</span>Sidewalk Low-Level and Preference</a></span></li><li><span><a href="#Sidewalk-Mid-Level-and-Preference" data-toc-modified-id="Sidewalk-Mid-Level-and-Preference-9.1.2"><span class="toc-item-num">9.1.2&nbsp;&nbsp;</span>Sidewalk Mid-Level and Preference</a></span></li></ul></li><li><span><a href="#Road-OLS" data-toc-modified-id="Road-OLS-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Road OLS</a></span><ul class="toc-item"><li><span><a href="#Road-Low-Level-and-Preference" data-toc-modified-id="Road-Low-Level-and-Preference-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Road Low-Level and Preference</a></span></li><li><span><a href="#Road-Mid-Level-and-Preference" data-toc-modified-id="Road-Mid-Level-and-Preference-9.2.2"><span class="toc-item-num">9.2.2&nbsp;&nbsp;</span>Road Mid-Level and Preference</a></span></li></ul></li><li><span><a href="#Emily-Talen-OLS" data-toc-modified-id="Emily-Talen-OLS-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Emily Talen OLS</a></span><ul class="toc-item"><li><span><a href="#Talen-Low-Level-and-Preference" data-toc-modified-id="Talen-Low-Level-and-Preference-9.3.1"><span class="toc-item-num">9.3.1&nbsp;&nbsp;</span>Talen Low-Level and Preference</a></span></li><li><span><a href="#Talen-Mid-Level-and-Preference" data-toc-modified-id="Talen-Mid-Level-and-Preference-9.3.2"><span class="toc-item-num">9.3.2&nbsp;&nbsp;</span>Talen Mid-Level and Preference</a></span></li></ul></li><li><span><a href="#Omid-Imgs-OLS" data-toc-modified-id="Omid-Imgs-OLS-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Omid Imgs OLS</a></span><ul class="toc-item"><li><span><a href="#Omid-Low-Level-and-Preference" data-toc-modified-id="Omid-Low-Level-and-Preference-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>Omid Low-Level and Preference</a></span></li><li><span><a href="#Omid-Mid-Level-and-Preference" data-toc-modified-id="Omid-Mid-Level-and-Preference-9.4.2"><span class="toc-item-num">9.4.2&nbsp;&nbsp;</span>Omid Mid-Level and Preference</a></span></li></ul></li></ul></li><li><span><a href="#Low&amp;Mid-OLS---Preference" data-toc-modified-id="Low&amp;Mid-OLS---Preference-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Low&amp;Mid OLS - Preference</a></span><ul class="toc-item"><li><span><a href="#Sidewalk---Preference" data-toc-modified-id="Sidewalk---Preference-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Sidewalk - Preference</a></span></li><li><span><a href="#Road---Preference" data-toc-modified-id="Road---Preference-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Road - Preference</a></span></li><li><span><a href="#Talen---Preference" data-toc-modified-id="Talen---Preference-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Talen - Preference</a></span></li><li><span><a href="#Omid---Preference" data-toc-modified-id="Omid---Preference-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>Omid - Preference</a></span></li></ul></li><li><span><a href="#Figure-Creation" data-toc-modified-id="Figure-Creation-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Figure Creation</a></span></li></ul></div>

# %% [markdown]
# ## Importing Necessary Packages

# %%
import numpy as np
from scipy.stats import pearsonr
from sklearn import datasets
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler 
from statsmodels.iolib.summary2 import summary_col
from statsmodels.api import add_constant
from sklearn.decomposition import PCA

# %% [markdown]
# ## Creating Functions

# %%
#functions
def standardize_data(data):
    scaler = StandardScaler()
    standardized = scaler.fit_transform(data)
    df_standardized = pd.DataFrame(standardized)
    return df_standardized


def combine_ratings_and_features(lowleveldata, midleveldata, ratingsdata):
    all_feat = pd.concat([lowleveldata, midleveldata], axis=1)
    all_feat.rename(columns={'const': 'Constant'})
    all_feat_ratings = pd.concat([all_feat, ratingsdata], axis=1)
    return all_feat_ratings


def run_reg(rating, data):
    reg = sm.OLS(rating, data).fit()
    return reg.summary()


def create_reg_table(*args):
    reg_list = []
    for a in len(args):
        reg_list.append(a)
    reg_table = summary_col([reg_list], stars=True, float_format='%0.2f')
    return reg_table


def corrfunc(x, y, ax=None, **kws):
    """Plot the correlation coefficient in the top left corner of a plot."""
    r, _ = pearsonr(x, y)
    ax = ax or plt.gca()
    corrcoeff = 'r'
    ax.annotate(f'{corrcoeff} = {r:.2f}', xy=(.1, .9), xycoords=ax.transAxes)


def create_ratings_corrgram(ratings):
    """creating a correlation matrix for all perceptual qualities."""
    corrgram_qualities = sns.pairplot(ratings, kind='reg', diag_kind="kde",
                                      plot_kws={'line_kws': {'color': 'black'}, 'scatter_kws': {'alpha': 0.5}})
    corrgram_qualities.set(xlim=(0.0, 1.0), ylim=(0.0, 1.0))
    corrgram_qualities.map_upper(corrfunc)
    corrgram_qualities.map_lower(corrfunc)
    corrgram_qualities.map_diag(sns.distplot)
    return plt.show()


def create_ratings_and_feat_corrgram(all_feat_ratings):
    """creating a correlation matrix for all perceptual qualities and features."""
    sns.set(style="white")
    f, ax = plt.subplots(figsize=(40, 40))
    sns.set(font_scale=1.99)
    sns.heatmap(all_feat_ratings.corr(), annot=True, fmt='.01g', vmin=-1, vmax=1, center=0,
                          annot_kws={"size": 17})
    return ax.tick_params(labelsize=27)

def standardized_low_boxplot(df_standardized):
    f, ax = plt.subplots(figsize=(25, 15))
    sns.boxplot(data=df_standardized)
    ax.tick_params(labelsize=22)
    #plt.title("Visual Features - Standardized",
    #        fontsize=40)  # You can comment this line out if you don't need title
    return plt.show()

def standardized_mid_boxplot(df_standardized):
    sns.set(font_scale=1.99)
    plt.figure(figsize=(20,17))
    g = sns.boxplot(data = df_standardized)
    #ax.tick_params(labelsize=90)
   # plt.title("Mid-Level Visual Features - Standardized", fontsize=40) 
    g.set_xticklabels(g.get_xticklabels(),rotation=45)
    plt.show()

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Import Low-Level Data

# %%
low_lvl_sidewalk_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/Streetviewimages_avFeaturesNofix1.csv")
low_lvl_road_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/Roadviewimages_avFeaturesNofix1.csv")
low_lvl_talen_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/Emily_Images_avFeaturesNofix1.csv")
low_lvl_img307 = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/omidsimageslowlvl_new.csv")

# %%
low_lvl_sidewalk_imgs = pd.DataFrame.sort_index(low_lvl_sidewalk_imgs, axis=0)
low_lvl_sidewalk_imgs = low_lvl_sidewalk_imgs.head(552) #using the first 552 images only
low_lvl_sidewalk_imgs
# Out:
#            ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0    0.096087  1.449011  0.159335  0.616733  1.931828  0.087734  0.268460
# 1    0.109095  0.997311  0.320123  0.540615  1.099389  0.222382  0.205563
# 2    0.123047 -2.417349  0.137197  0.449901  1.476390  0.129007  0.169043
# 3    0.114585  0.269994  0.249306  0.587993  1.492316  0.238563  0.257318
# 4    0.083636  0.712665  0.171798  0.646293  2.331845  0.157754  0.218315
# ..        ...       ...       ...       ...       ...       ...       ...
# 547  0.097567  2.185402  0.204579  0.586883  1.946461  0.139569  0.181917
# 548  0.089502  1.318654  0.127837  0.689174  1.984397  0.133550  0.232847
# 549  0.102450  0.682720  0.173729  0.536139  1.502872  0.154223  0.210125
# 550  0.095024  1.020084  0.114356  0.696806  1.638546  0.135332  0.213527
# 551  0.105519  1.320850  0.153546  0.545817  1.677392  0.167647  0.218740
#
#       Entropy       SED      NSED
# 0    7.633971  0.042888  0.057226
# ...

# %%
low_lvl_road_imgs = pd.DataFrame.sort_index(low_lvl_road_imgs, axis=0)
low_lvl_road_imgs = low_lvl_road_imgs.head(552) #using the first 552 images only
low_lvl_road_imgs
# Out:
#            ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0    0.104992  1.503163  0.248001  0.544014  1.516762  0.160157  0.216398
# 1    0.093361  2.178209  0.224004  0.545132  2.217821  0.145341  0.180773
# 2    0.101782 -2.526767  0.147735  0.549103  1.343882  0.141703  0.238748
# 3    0.094575 -2.160527  0.177408  0.626480  1.863602  0.166173  0.259045
# 4    0.092790  0.952140  0.246620  0.562286  1.959104  0.201825  0.189645
# ..        ...       ...       ...       ...       ...       ...       ...
# 547  0.094440  2.697417  0.166880  0.554870  1.687378  0.117659  0.188224
# 548  0.084764  1.331402  0.084060  0.701264  1.471362  0.117209  0.210968
# 549  0.092013  1.192845  0.123802  0.644711  1.635935  0.117633  0.208003
# 550  0.101006  1.055323  0.118324  0.598679  1.379798  0.131547  0.213785
# 551  0.082035  1.104081  0.121279  0.686038  2.071495  0.113436  0.211183
#
#       Entropy       SED      NSED
# 0    7.560045  0.058960  0.055299
# ...

# %%
low_lvl_talen_imgs
# Out:
#             ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0     0.116773 -1.744122  0.184585  0.557853  1.427965  0.174967  0.265254
# 1     0.101375  2.188787  0.194649  0.526473  2.236823  0.173917  0.292405
# 2     0.093291  2.524703  0.192902  0.575044  1.073009  0.165779  0.347674
# 3     0.103258 -3.100124  0.258880  0.477369  0.828234  0.224116  0.342817
# 4     0.089973  3.013109  0.248481  0.570676  1.323300  0.204190  0.341872
# ...        ...       ...       ...       ...       ...       ...       ...
# 1114  0.133429  0.297715  0.128710  0.534989  1.348431  0.132062  0.257242
# 1115  0.125232  1.086993  0.126128  0.539192  1.158345  0.143211  0.310945
# 1116  0.122649  0.490924  0.172006  0.487326  1.202984  0.165152  0.257395
# 1117  0.098162  0.639280  0.141138  0.590354  1.043509  0.145232  0.267945
# 1118  0.116919  0.661746  0.101573  0.581783  1.107688  0.109737  0.243554
#
#        Entropy       SED      NSED
# ...

# %%
low_lvl_img307
# Out:
#            ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0    0.098011  0.562309  0.353688  0.648315  0.759563  0.251842  0.219514
# 1    0.113038  0.068109  0.167558  0.472942  1.428838  0.193758  0.234948
# 2    0.125331  0.551906  0.150498  0.580751  0.867139  0.163630  0.198025
# 3    0.165978  1.615438  0.297588  0.456856  0.911830  0.183771  0.222387
# 4    0.182497  1.123014  0.517123  0.494905  0.323936  0.232047  0.272794
# ..        ...       ...       ...       ...       ...       ...       ...
# 302  0.101696  1.725459  0.169648  0.482843  1.115057  0.179569  0.307204
# 303  0.144634  1.220015  0.423482  0.433780  0.709376  0.279479  0.218785
# 304  0.148004  0.997970  0.302571  0.437244  0.591311  0.206390  0.241288
# 305  0.164840  1.082161  0.332593  0.530156  0.278945  0.144961  0.149227
# 306  0.163954  1.750064  0.365290  0.433999  0.528981  0.200280  0.204653
#
#       Entropy       SED      NSED
# 0    7.728764  0.100877  0.024560
# ...

# %% [markdown]
# ### Import Mid-Level Data

# %%
mid_lvl_sidewalk_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/midlvlsidewalk_new.csv", index_col=0)
mid_lvl_road_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/CSVs_Tianxin/mid_level_output_road.csv", index_col=0)
mid_lvl_talen_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/EmilyImages_object_ratios.csv", index_col=0)
mid_lvl_img307 = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/images307_object_ratios.csv", index_col=0)

# %%
mid_lvl_sidewalk_imgs = pd.DataFrame.sort_index(mid_lvl_sidewalk_imgs, axis=0)
mid_lvl_sidewalk_imgs = mid_lvl_sidewalk_imgs.head(552) #using the first 552 images only
mid_lvl_sidewalk_imgs


mid_lvl_sidewalk_imgs.columns=['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']

mid_lvl_sidewalk_imgs['Wall']
# Out:
# id
# p1s00001_pred_label_img    0.000000
# p1s00002_pred_label_img    0.000000
# p1s00003_pred_label_img    0.000000
# p1s00004_pred_label_img    0.000000
# p1s00005_pred_label_img    0.000553
#                              ...
# p1s00548_pred_label_img    0.000085
# p1s00549_pred_label_img    0.000000
# p1s00550_pred_label_img    0.014310
# p1s00551_pred_label_img    0.000563
# p1s00552_pred_label_img    0.000000
# Name: Wall, Length: 552, dtype: float64

# %%
mid_lvl_road_imgs = pd.DataFrame.sort_index(mid_lvl_road_imgs, axis=0)
mid_lvl_road_imgs = mid_lvl_road_imgs.head(552) #using the first 552 images only
mid_lvl_road_imgs
# Out:
#                                 0         1         2         3         4  \
# id
# p1r00001_pred_label_img  0.283031  0.091491  0.042314  0.002217  0.001855
# p1r00002_pred_label_img  0.359121  0.028317  0.164365  0.000000  0.001204
# p1r00003_pred_label_img  0.265622  0.045801  0.256289  0.000000  0.000101
# p1r00004_pred_label_img  0.372926  0.029255  0.096943  0.000000  0.031263
# p1r00005_pred_label_img  0.357939  0.004717  0.036868  0.000000  0.003883
# ...                           ...       ...       ...       ...       ...
# p1r00548_pred_label_img  0.266370  0.014961  0.122559  0.000000  0.001536
# p1r00549_pred_label_img  0.368437  0.030671  0.109199  0.005150  0.025329
# p1r00550_pred_label_img  0.301751  0.072712  0.260781  0.000000  0.002181
# p1r00551_pred_label_img  0.281367  0.075260  0.286257  0.000651  0.025508
# p1r00552_pred_label_img  0.391169  0.011995  0.131123  0.000003  0.002747
#
# ...

# %%
mid_lvl_talen_imgs
# Out:
#             pcnt_road  pcnt_sidewalk  pcnt_building  pcnt_wall  pcnt_fence  \
# image_name
# STIM0001     0.043968       0.244755       0.035085   0.000000    0.018417
# STIM0002     0.084339       0.030955       0.280509   0.000000    0.000587
# STIM0003     0.101739       0.057976       0.062473   0.000392    0.019086
# STIM0004     0.072013       0.032293       0.160499   0.000000    0.044067
# STIM0005     0.067359       0.015763       0.232855   0.000142    0.007326
# ...               ...            ...            ...        ...         ...
# STIM1115     0.125181       0.049316       0.146713   0.000000    0.000152
# STIM1116     0.196597       0.014132       0.067538   0.006349    0.006989
# STIM1117     0.251070       0.047009       0.143681   0.000000    0.025819
# STIM1118     0.304790       0.098669       0.171145   0.000000    0.010486
# STIM1119     0.357064       0.027659       0.027748   0.000051    0.027360
#
# ...

# %%
mid_lvl_img307
# Out:
#                       pcnt_road  pcnt_sidewalk  pcnt_building  pcnt_wall  \
# image_name
# AVAM_02                0.000000       0.000183       0.093684   0.000000
# Urban_Image_37         0.373978       0.034096       0.180081   0.000000
# BaltParksKeySchool     0.000000       0.003430       0.150145   0.000000
# Childrens1             0.000540       0.007273       0.060989   0.031171
# Restoration_Image_30   0.000952       0.000003       0.000000   0.000000
# ...                         ...            ...            ...        ...
# Urban_Image_31         0.143052       0.088704       0.652896   0.000000
# Restoration_Image_06   0.000000       0.000000       0.000358   0.000000
# Urban_Image_09         0.313938       0.032661       0.162917   0.000044
# CommunityMeditation3   0.000000       0.034605       0.170082   0.000000
# meridian1              0.003648       0.010527       0.122824   0.000000
#
#                       pcnt_fence  pcnt_pole  pcnt_traffic_light  \
# image_name
# ...

# %% [markdown]
# ### Import Ratings Data

# %%
ratings_sidewalk_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/CSVs_Tianxin/scoreTable_2.csv", index_col=0)
ratings_road_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/CSVs_Tianxin/scoreTable_2.csv", index_col=0)
ratings_talen_imgs = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/scoreTable_emily.csv", index_col=0)
ratings_img307 = pd.read_csv("/Volumes/GNA_SCHOOL_HD/street_psych/All_CSV_Files/ratingsAveraged_images307.csv", index_col=0)

# %%
ratings_sidewalk_imgs = ratings_sidewalk_imgs.drop(['Humanscale', 'Order'], axis=1)
ratings_sidewalk_imgs = ratings_sidewalk_imgs.rename(columns={"Order2" : "Disorder", "Humanscale2" : "Humanscale"})
ratings_sidewalk_imgs
# Out:
#           Walkability  Preference  Imageability  Complexity  Enclosure  \
# Image_ID
# 1            0.266667    0.262295      0.277778    0.241379   0.278689
# 2            0.716667    0.704918      0.722222    0.844828   0.196721
# 3            0.333333    0.327869      0.296296    0.500000   0.475410
# 4            0.566667    0.606557      0.592593    0.689655   0.377049
# 5            0.166667    0.295082      0.259259    0.500000   0.131148
# ...               ...         ...           ...         ...        ...
# 548          0.183333    0.213115      0.166667    0.568966   0.098361
# 549          0.133333    0.131148      0.092593    0.206897   0.147541
# 550          0.083333    0.098361      0.240741    0.482759   0.229508
# 551          0.133333    0.180328      0.129630    0.155172   0.295082
# 552          0.133333    0.131148      0.074074    0.172414   0.213115
#
#           Transparency  Humanscale  Disorder
# Image_ID
# 1             0.375000    0.428571  0.222222
# ...

# %%
ratings_road_imgs = ratings_road_imgs.drop(['Humanscale', 'Order'], axis=1)
ratings_road_imgs = ratings_road_imgs.rename(columns={"Order2" : "Disorder", "Humanscale2" : "Humanscale"})
ratings_road_imgs
# Out:
#           Walkability  Preference  Imageability  Complexity  Enclosure  \
# Image_ID
# 1            0.266667    0.262295      0.277778    0.241379   0.278689
# 2            0.716667    0.704918      0.722222    0.844828   0.196721
# 3            0.333333    0.327869      0.296296    0.500000   0.475410
# 4            0.566667    0.606557      0.592593    0.689655   0.377049
# 5            0.166667    0.295082      0.259259    0.500000   0.131148
# ...               ...         ...           ...         ...        ...
# 548          0.183333    0.213115      0.166667    0.568966   0.098361
# 549          0.133333    0.131148      0.092593    0.206897   0.147541
# 550          0.083333    0.098361      0.240741    0.482759   0.229508
# 551          0.133333    0.180328      0.129630    0.155172   0.295082
# 552          0.133333    0.131148      0.074074    0.172414   0.213115
#
#           Transparency  Humanscale  Disorder
# Image_ID
# 1             0.375000    0.428571  0.222222
# ...

# %%
ratings_talen_imgs
# Out:
#           Walkability  Preference  Imageability  Complexity  Enclosure  \
# Image_ID
# 1            0.176471    0.382353      0.212121    0.424242   0.195122
# 2            0.472222    0.400000      0.411765    0.714286   0.378378
# 3            0.117647    0.225000      0.153846    0.076923   0.135135
# 4            0.324324    0.272727      0.250000    0.176471   0.250000
# 5            0.225806    0.312500      0.406250    0.181818   0.243902
# ...               ...         ...           ...         ...        ...
# 1115         0.457143    0.290323      0.363636    0.307692   0.342105
# 1116         0.333333    0.485714      0.297297    0.314286   0.184211
# 1117         0.413793    0.382353      0.333333    0.368421   0.388889
# 1118         0.354839    0.366667      0.333333    0.394737   0.189189
# 1119         0.138889    0.135135      0.090909    0.205882   0.083333
#
#           Transparency  Humanscale  Disorder
# Image_ID
# 1             0.108108    0.444444  0.516129
# ...

# %%
ratings_img307
# Out:
#                              Nat      Pref
# ImageName
# A_Wider_Circle_006.jpg  2.379774  4.450433
# A_Wider_Circle_007.jpg  2.724473  4.603360
# A_Wider_Circle_017.jpg  3.230627  4.934809
# Amazing_Grace_086.jpg   2.798603  3.368730
# Amazing_Grace_087.jpg   2.705261  3.896745
# ...                          ...       ...
# Urban_Image_46.BMP      2.127817  3.348891
# Urban_Image_47.BMP      1.366264  3.117589
# Urban_Image_48.BMP      3.549555  3.133475
# Urban_Image_49.BMP      1.260935  2.311136
# Urban_Image_50.BMP      1.552391  3.815903
#
# [307 rows x 2 columns]

# %% [markdown]
# ## Standardizing Data

# %% [markdown]
# ### Standardizing Low-Level Data

# %%
standardized_low_sidewalk = standardize_data(low_lvl_sidewalk_imgs)
standardized_low_sidewalk.columns = ['ED', 'Hue', 'Sat','Lum', 'sdHue', 'sdSat', 'sdBright',
'Entropy', 'StraightED', 'NonStraightED']

standardized_low_road = standardize_data(low_lvl_road_imgs)
standardized_low_road.columns = ['ED', 'Hue', 'Sat','Lum', 'sdHue', 'sdSat', 'sdBright',
'Entropy', 'StraightED', 'NonStraightED']

standardized_low_talen = standardize_data(low_lvl_talen_imgs)
standardized_low_talen.columns = ['ED', 'Hue', 'Sat','Lum', 'sdHue', 'sdSat', 'sdBright',
'Entropy', 'StraightED', 'NonStraightED']

standardized_low_omid = standardize_data(low_lvl_img307)
standardized_low_omid.columns = ['ED', 'Hue', 'Sat','Lum', 'sdHue', 'sdSat', 'sdBright',
'Entropy', 'StraightED', 'NonStraightED']

# %%
standardized_low_sidewalk
# Out:
#            ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0   -0.680335  0.583962 -0.852641  0.951346  1.012445 -1.861439  1.581820
# 1    0.165355  0.247063  1.458950  0.125912 -0.688790  1.424584 -0.087112
# 2    1.072418 -2.299756 -1.170917 -0.857808  0.081678 -0.854184 -1.056143
# 3    0.522275 -0.295405  0.440833  0.639681  0.114225  1.819494  1.286169
# 4   -1.489835  0.034760 -0.673469  1.271902  1.829950 -0.152622  0.251257
# ..        ...       ...       ...       ...       ...       ...       ...
# 547 -0.584147  1.133198 -0.202194  0.627651  1.042351 -0.596431 -0.714546
# 548 -1.108471  0.486736 -1.305484  1.736904  1.119878 -0.743319  0.636842
# 549 -0.266696  0.012425 -0.645710  0.077375  0.135798 -0.238798  0.033937
# 550 -0.749433  0.264048 -1.499300  1.819671  0.413071 -0.699828  0.124220
# 551 -0.067125  0.488374 -0.935880  0.182326  0.492461  0.088806  0.262533
#
#       Entropy  StraightED  NonStraightED
# ...

# %%
standardized_low_road
# Out:
#            ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0    0.108444  0.555783  0.782841 -0.209835 -0.081732  0.133192  0.099082
# 1   -0.766532  1.004774  0.429015 -0.196788  1.524139 -0.221090 -1.070821
# 2   -0.133013 -2.124626 -0.695563 -0.150461 -0.477736 -0.308082  0.833054
# 3   -0.675190 -1.881031 -0.258039  0.752158  0.712753  0.277053  1.499626
# 4   -0.809509  0.189284  0.762487  0.003318  0.931514  1.129580 -0.779451
# ..        ...       ...       ...       ...       ...       ...       ...
# 547 -0.685352  1.350112 -0.413269 -0.083197  0.309088 -0.883050 -0.826118
# 548 -1.413274  0.441541 -1.634430  1.624546 -0.185727 -0.893797 -0.079216
# 549 -0.867914  0.349383 -1.048443  0.964837  0.191251 -0.883670 -0.176605
# 550 -0.191419  0.257914 -1.129211  0.427854 -0.395467 -0.550951  0.013299
# 551 -1.618610  0.290344 -1.085643  1.446924  1.188960 -0.984036 -0.072167
#
#       Entropy  StraightED  NonStraightED
# ...

# %%
standardized_low_talen
# Out:
#             ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0     1.265458 -0.851859 -0.270888  0.372972  0.158647 -0.011795 -0.293687
# 1     0.091315  1.524110 -0.156125 -0.116810  1.790921 -0.035404  0.548584
# 2    -0.525075  1.727045 -0.176056  0.641278 -0.557655 -0.218428  2.263158
# 3     0.234903 -1.671054  0.576315 -0.883231 -1.051611  1.093536  2.112478
# 4    -0.778060  2.022104  0.457735  0.573101 -0.052567  0.645432  2.083170
# ...        ...       ...       ...       ...       ...       ...       ...
# 1114  2.535470  0.381666 -0.908047  0.016100 -0.001855 -0.976698 -0.542233
# 1115  1.910454  0.858489 -0.937488  0.081708 -0.385447 -0.725969  1.123742
# 1116  1.713471  0.498388 -0.414334 -0.727826 -0.295367 -0.232528 -0.537495
# 1117 -0.153634  0.588014 -0.766334  0.880246 -0.617186 -0.680503 -0.210218
# 1118  1.276596  0.601586 -1.217495  0.746460 -0.487674 -1.478777 -0.966863
#
#        Entropy  StraightED  NonStraightED
# ...

# %%
standardized_low_omid
# Out:
#            ED       Hue       Sat       Lum     sdHue     sdSat  sdBright  \
# 0   -1.232490 -0.082796  0.119985  1.617739 -0.497826  0.820966 -0.950572
# 1   -0.617268 -0.427681 -1.478633 -0.497113  1.166007 -0.206832 -0.572974
# 2   -0.113970 -0.090056 -1.625161  0.802979 -0.230390 -0.739948 -1.476310
# 3    1.550131  0.652147 -0.361839 -0.691105 -0.119287 -0.383548 -0.880278
# 4    2.226447  0.308501  1.523688 -0.232258 -1.580803  0.470686  0.352914
# ..        ...       ...       ...       ...       ...       ...       ...
# 302 -1.081626  0.728927 -1.460687 -0.377715  0.385941 -0.457906  1.194757
# 303  0.676321  0.376195  0.719431 -0.969375 -0.622591  1.309998 -0.968416
# 304  0.814262  0.221237 -0.319040 -0.927605 -0.916105  0.016698 -0.417879
# 305  1.503559  0.279991 -0.061190  0.192838 -1.692653 -1.070291 -2.670133
# 306  1.467275  0.746097  0.219631 -0.966733 -1.071057 -0.091418 -1.314138
#
#       Entropy  StraightED  NonStraightED
# ...

# %% [markdown]
# ### Standardizing Mid-Level Data

# %%
standardized_mid_sidewalk = standardize_data(mid_lvl_sidewalk_imgs)
standardized_mid_sidewalk.columns=['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']

standardized_mid_road = standardize_data(mid_lvl_road_imgs)
standardized_mid_road.columns=['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']

standardized_mid_talen = standardize_data(mid_lvl_talen_imgs)
standardized_mid_talen.columns=['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']

standardized_mid_omid = standardize_data(mid_lvl_img307)
standardized_mid_omid.columns=['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']

# %% [markdown]
# ### Standardizing Rating Data

# %%
standardized_ratings_sidewalk = standardize_data(ratings_sidewalk_imgs)
standardized_ratings_sidewalk.columns=["Walkability", "Preference", "Imageability", "Complexity", "Enclosure", "Transparency", "Humanscale", "Disorder"]

standardized_ratings_road = standardize_data(ratings_road_imgs)
standardized_ratings_road.columns=["Walkability", "Preference", "Imageability", "Complexity", "Enclosure", "Transparency", "Humanscale", "Disorder"]

standardized_ratings_talen = standardize_data(ratings_talen_imgs)
standardized_ratings_talen.columns=["Walkability", "Preference", "Imageability", "Complexity", "Enclosure", "Transparency", "Humanscale", "Disorder"]

standardized_ratings_omid = standardize_data(ratings_img307)
standardized_ratings_omid.columns=['Naturalness', 'Preference']

# %%
standardized_ratings_sidewalk
# Out:
#      Walkability  Preference  Imageability  Complexity  Enclosure  \
# 0      -0.328069   -0.396165     -0.338632   -0.538060  -0.332572
# 1       1.841204    2.017750      2.287950    2.898411  -0.820297
# 2      -0.006695   -0.038547     -0.229192    0.934713   0.837968
# 3       1.118113    1.481325      1.521864    2.014747   0.252698
# 4      -0.810130   -0.217356     -0.448073    0.934713  -1.210477
# ..           ...         ...           ...         ...        ...
# 547    -0.729786   -0.664377     -0.995278    1.327453  -1.405567
# 548    -0.970817   -1.111399     -1.433042   -0.734430  -1.112932
# 549    -1.211847   -1.290207     -0.557514    0.836528  -0.625207
# 550    -0.970817   -0.843186     -1.214160   -1.028985  -0.235027
# 551    -0.970817   -1.111399     -1.542483   -0.930800  -0.722752
#
#      Transparency  Humanscale  Disorder
# 0        0.167202    0.599738 -0.738702
# 1        1.115442   -1.113798  0.084024
# 2        1.984662   -0.314148 -0.224498
# ...

# %%
standardized_ratings_road
# Out:
#      Walkability  Preference  Imageability  Complexity  Enclosure  \
# 0      -0.328069   -0.396165     -0.338632   -0.538060  -0.332572
# 1       1.841204    2.017750      2.287950    2.898411  -0.820297
# 2      -0.006695   -0.038547     -0.229192    0.934713   0.837968
# 3       1.118113    1.481325      1.521864    2.014747   0.252698
# 4      -0.810130   -0.217356     -0.448073    0.934713  -1.210477
# ..           ...         ...           ...         ...        ...
# 547    -0.729786   -0.664377     -0.995278    1.327453  -1.405567
# 548    -0.970817   -1.111399     -1.433042   -0.734430  -1.112932
# 549    -1.211847   -1.290207     -0.557514    0.836528  -0.625207
# 550    -0.970817   -0.843186     -1.214160   -1.028985  -0.235027
# 551    -0.970817   -1.111399     -1.542483   -0.930800  -0.722752
#
#      Transparency  Humanscale  Disorder
# 0        0.167202    0.599738 -0.738702
# 1        1.115442   -1.113798  0.084024
# 2        1.984662   -0.314148 -0.224498
# ...

# %%
standardized_ratings_talen
# Out:
#       Walkability  Preference  Imageability  Complexity  Enclosure  \
# 0       -1.083078    0.327144     -0.721013    0.447036  -0.715858
# 1        0.900115    0.459700      0.411867    1.957607   0.197174
# 2       -1.477525   -0.854817     -1.051695   -1.361834  -1.014728
# 3       -0.091629   -0.496312     -0.506069   -0.843381  -0.442441
# 4       -0.752251   -0.197558      0.380574   -0.815531  -0.472820
# ...           ...         ...           ...         ...        ...
# 1114     0.798999   -0.364145      0.138762   -0.159967   0.016452
# 1115    -0.031218    1.103546     -0.237680   -0.125628  -0.770221
# 1116     0.508313    0.327144     -0.033193    0.156313   0.249540
# 1117     0.112988    0.209316     -0.033193    0.293368  -0.745416
# 1118    -1.335086   -1.529840     -1.408833   -0.690202  -1.272818
#
#       Transparency  Humanscale  Disorder
# 0        -1.116452    0.781183  0.970461
# 1         1.425430   -1.070382  1.586034
# ...

# %%
standardized_ratings_omid
# Out:
#      Naturalness  Preference
# 0      -0.672159    0.238289
# 1      -0.477989    0.388593
# 2      -0.192872    0.714356
# 3      -0.436232   -0.824860
# 4      -0.488812   -0.305902
# ..           ...         ...
# 302    -0.814087   -0.844359
# 303    -1.243072   -1.071693
# 304    -0.013219   -1.056080
# 305    -1.302404   -1.864314
# 306    -1.138226   -0.385358
#
# [307 rows x 2 columns]

# %% [markdown]
# ## PCA for Mid-Level Features

# %%
standardized_mid_sidewalk
pca_mid_lvl_sidewalk = PCA(n_components=20).fit(standardized_mid_sidewalk)
print(pca_mid_lvl_sidewalk.explained_variance_ratio_)
print(pca_mid_lvl_sidewalk.components_)

T_pca_mid_lvl_sidewalk = pca_mid_lvl_sidewalk.transform(standardized_mid_sidewalk)

type(T_pca_mid_lvl_sidewalk)
#print(T_pca_mid_lvl_sidewalk)

df_t_pca_mid_sidewalk = pd.DataFrame(T_pca_mid_lvl_sidewalk, columns = ['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled'])

df_t_pca_mid_sidewalk
# Out:
# [1.24642857e-01 1.17896462e-01 9.06232639e-02 7.89041766e-02
#  6.19736082e-02 6.01624612e-02 5.21969057e-02 5.05676240e-02
#  4.89990131e-02 4.66623902e-02 4.43060797e-02 4.31801593e-02
#  3.98597586e-02 3.83419577e-02 2.98487396e-02 2.46768281e-02
#  2.28541348e-02 2.08814658e-02 3.42211460e-03 2.33430677e-16]
# [[ 2.60658496e-02  2.65088417e-01  3.76460455e-01 -3.08794703e-02
#   -1.19430223e-01  4.23140263e-01  3.26912669e-01  2.09627223e-01
#   -4.12922832e-01 -3.17707520e-01 -1.66360618e-02  2.35358223e-01
#    1.64214338e-01 -6.43820098e-02 -3.52214103e-02  5.88741693e-02
#   -2.18647303e-02  5.33143379e-02  2.49722803e-01  1.16757463e-01]
#  [-5.45209524e-01  3.47059226e-01  1.02697857e-01 -2.68535657e-02
#    2.48716245e-01  6.27795098e-02  5.57351009e-02  1.37062017e-01
#    3.28401713e-01  2.96696238e-01 -4.68133186e-01  3.39338567e-02
#    4.49221953e-02  1.06714609e-03 -1.14827688e-01 -6.11869589e-02
#   -5.80796456e-02  2.01883603e-02  8.07726365e-02  1.94692376e-01]
# ...

# %%
standardized_mid_sidewalk
pca_mid_lvl_side = PCA(n_components=20).fit(standardized_mid_sidewalk)

df = pd.DataFrame({'Variance':pca_mid_lvl_side.explained_variance_ratio_,
             'Principle Component':['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']})

fig, ax = plt.subplots(figsize = (12,6))  
g = sns.barplot(x='Principle Component',y="Variance", 
           data=df, color="c")
sns.set(font_scale=.980)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
sns.set(font_scale = 1.5)
plt.figure(figsize=(15, 50))
g.tick_params(labelsize=15)
plt.show()

fig, ax = plt.subplots(figsize = (12,6))  
s = sns.scatterplot(x='Principle Component',y="Variance", 
           data=df, color="c")
sns.set(font_scale=.980)
s.set_xticklabels(g.get_xticklabels(),rotation=45)
sns.set(font_scale = 1.5)
plt.figure(figsize=(15, 50))
s.tick_params(labelsize=15)
plt.show()

# %%
standardized_mid_road 
pca_mid_lvl_road = PCA(n_components=20).fit(standardized_mid_road)

df = pd.DataFrame({'Variance':pca_mid_lvl_road.explained_variance_ratio_,
             'Principle Component':['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled']})

fig, ax = plt.subplots(figsize = (12,6))  
g = sns.barplot(x='Principle Component',y="Variance", 
           data=df, color="c")
sns.set(font_scale=.980)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
sns.set(font_scale = 1.5)
plt.figure(figsize=(15, 50))
g.tick_params(labelsize=15)
plt.show()

fig, ax = plt.subplots(figsize = (12,6))  
s = sns.scatterplot(x='Principle Component',y="Variance", 
           data=df, color="c")
sns.set(font_scale=.980)
s.set_xticklabels(g.get_xticklabels(),rotation=45)
sns.set(font_scale = 1.5)
plt.figure(figsize=(15, 50))
s.tick_params(labelsize=15)
plt.show()

# %%
loadings = pca_mid_lvl_road.components_.T * np.sqrt(pca_mid_lvl_road.explained_variance_)
loadings
loading_matrix = pd.DataFrame(loadings, columns=['Road', 'Sidewalk', 'Building', 'Wall','Fence', 'Pole', 'Traffic Light', 'Traffic Sign', 'Vegetation','Terrain', 'Sky',
'Person', 'Rider', 'Car','Truck', 'Bus', 'Train','Motorcycle','Bicycle', 'Unlabeled'])
loading_matrix

fig, ax = plt.subplots(figsize = (12,6))  
g = sns.barplot(data=loading_matrix, color="c")
sns.set(font_scale=1.5)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
sns.set(font_scale = 1.5)
plt.figure(figsize=(20, 55))
g.tick_params(labelsize=14)
plt.show()

# %%
pca_standardized_mid_talen = PCA(n_components=20).fit(standardized_mid_talen)

# %%
pca_standardized_mid_omid = PCA(n_components=20).fit(standardized_mid_omid)

# %% [markdown]
# ## Correlation Matrix for Mid-Level Feats

# %%
standardized_mid_sidewalk
# Out:
#          Road  Sidewalk  Building      Wall     Fence      Pole  \
# 0    1.592145 -0.399671 -0.691806 -0.256668 -0.669962  0.067743
# 1    0.052586  1.586290 -0.175451 -0.256668 -0.359461 -0.389700
# 2   -0.706355 -0.407689  1.453308 -0.256668 -0.202923 -0.510901
# 3    0.783558 -0.943479  0.166854 -0.256668 -0.597858 -0.625535
# 4    1.479086 -0.905416 -1.306596 -0.205614  0.056232 -0.506797
# ..        ...       ...       ...       ...       ...       ...
# 547  0.124774 -0.916559 -0.565210 -0.248863 -0.259810 -0.255094
# 548  1.626464 -1.090782 -0.986422 -0.256668 -0.691812 -0.449617
# 549 -1.481460  0.488417  1.061203  1.063515  1.086528  0.548989
# 550  1.921537 -0.929785 -0.633947 -0.204713 -0.832119 -0.301057
# 551 -0.525813 -0.826844  1.413126 -0.256668 -0.832119 -1.150285
#
#      Traffic Light  Traffic Sign  Vegetation   Terrain       Sky    Person  \
# 0        -0.341201      0.019360   -0.385003 -0.525896  1.185182 -0.031355
# ...

# %%
def corrfunc(x, y, ax=None, **kws):
    """Plot the correlation coefficient in the top left corner of a plot."""
    r, _ = pearsonr(x, y)
    ax = ax or plt.gca()
    corrcoeff = 'r'
    ax.annotate(f'{corrcoeff} = {r:.2f}', xy=(.1, .9), xycoords=ax.transAxes)


corrgram_mid_side = sns.pairplot(standardized_mid_sidewalk, kind='reg', plot_kws={'line_kws':{'color':'black'}})
#corrgram_mid_side.set(xlim=(-2.0,2.0), ylim =(-2.0,2.0))
#corrgram_mid_side.map_upper(corrfunc)
#corrgram_mid_side.map_lower(corrfunc)
#corrgram_mid_side.map_diag(sns.distplot)
plt.show()

# %% [markdown]
# ## Concatenating all DataFrames to prep for OLS

# %% [markdown]
# ### Sidewalk

# %%
all_sidewalk_feat = combine_ratings_and_features(standardized_low_sidewalk, standardized_mid_sidewalk, standardized_ratings_sidewalk)
all_sidewalk_feat

# %% [markdown]
# ### Road

# %%
all_road_feat = combine_ratings_and_features(standardized_low_road, standardized_mid_road, standardized_ratings_road)
all_road_feat

# %% [markdown]
# ### Emily Talen Imgs

# %%
all_talen_feat = combine_ratings_and_features(standardized_low_talen, standardized_mid_talen, standardized_ratings_talen)
all_talen_feat

# %% [markdown]
# ### Omid Images (Img307)

# %%
all_omid_feat = combine_ratings_and_features(standardized_low_omid, standardized_mid_omid, standardized_ratings_omid)
all_omid_feat

# %% [markdown]
# ## Assigning 'Preference' to A Respective Variable

# %% [markdown]
# ### Sidewalk - Preference

# %%
preference_sidewalk = all_sidewalk_feat['Preference']    
preference_sidewalk

# %% [markdown]
# ### Road - Preference

# %%
preference_road = all_road_feat['Preference']    
preference_road

# %% [markdown]
# ### Emily Talen Imgs - Preference

# %%
preference_talen = all_talen_feat['Preference']    
preference_talen

# %% [markdown]
# ### Omid Images - Preference

# %%
preference_omid = all_omid_feat['Preference']    
preference_omid

# %% [markdown]
# ## Running OLS Regressions

# %% [markdown]
# ### Sidewalk OLS

# %% [markdown]
# #### Sidewalk Low-Level and Preference

# %%
ols_low_sidewalk_pref = print(run_reg(preference_sidewalk, standardized_low_sidewalk))

# %% [markdown]
# #### Sidewalk Mid-Level and Preference

# %%
#ols_mid_sidewalk_pref = print(run_reg(preference_sidewalk, standardized_mid_sidewalk))

print(preference_sidewalk)
print(standardized_mid_sidewalk)

sm.OLS(preference_sidewalk,standardized_mid_sidewalk).fit().summary()

# %% [markdown]
# ### Road OLS

# %% [markdown]
# #### Road Low-Level and Preference

# %%
ols_low_road_pref = print(run_reg(preference_road, standardized_low_road))

# %% [markdown]
# #### Road Mid-Level and Preference

# %%
ols_mid_road_pref = print(run_reg(preference_road, standardized_mid_road))

# %% [markdown]
# ### Emily Talen OLS

# %% [markdown]
# #### Talen Low-Level and Preference

# %%
ols_low_talen_pref =print(run_reg(preference_talen, standardized_low_talen))

# %% [markdown]
# #### Talen Mid-Level and Preference

# %%
ols_mid_talen_pref =print(run_reg(preference_talen, standardized_mid_talen))

# %% [markdown]
# ### Omid Imgs OLS

# %% [markdown]
# #### Omid Low-Level and Preference

# %%
ols_low_omid_pref = print(run_reg(preference_omid, standardized_low_omid))

# %% [markdown]
# #### Omid Mid-Level and Preference

# %%
ols_mid_omid_pref = print(run_reg(preference_omid, standardized_mid_omid))

# %% [markdown]
# ## Low&Mid OLS - Preference

# %% [markdown]
# ### Sidewalk - Preference

# %%
ols_low_mid_side = print(run_reg(preference_sidewalk, all_sidewalk_feat))

# %% [markdown]
# ### Road - Preference

# %%
ols_low_mid_road = print(run_reg(preference_road, all_road_feat))

# %% [markdown]
# ### Talen - Preference

# %%
ols_low_mid_talen = print(run_reg(preference_talen, all_talen_feat))

# %% [markdown]
# ### Omid - Preference

# %%
ols_low_mid_omid = print(run_reg(preference_omid, all_omid_feat))

# %% [markdown]
# ## Figure Creation

# %%
standardized_low_boxplot(standardized_low_sidewalk)

# %%
standardized_mid_boxplot(standardized_mid_sidewalk)

# %%
standardized_low_boxplot(standardized_low_road)

# %%
standardized_mid_boxplot(standardized_mid_road)

# %%
standardized_low_boxplot(standardized_low_talen)

# %%
standardized_mid_boxplot(standardized_mid_talen)

# %%
standardized_low_boxplot(standardized_low_omid)

# %%
standardized_mid_boxplot(standardized_mid_omid)

# %%
sns.distplot(all_sidewalk_feat['Wall'], bins=15)

all_sidewalk_feat['Wall']
